# %% [markdown]
# # 1 - Simple Sentiment Analysis
#
# In this series we'll be building a machine learning model to detect sentiment (i.e. detect if a sentence is positive or negative) using PyTorch and TorchText. This will be done on movie reviews, using the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/).
#
# In this first notebook, we'll start very simple to understand the general concepts whilst not really caring about good results. Further notebooks will build on this knowledge and we'll actually get good results.
#
# ### Introduction
#
# We'll be using a **recurrent neural network** (RNN) as they are commonly used in analysing sequences. An RNN takes in sequence of words, $X=\{x_1, ..., x_T\}$, one at a time, and produces a _hidden state_, $h$, for each word. We use the RNN _recurrently_ by feeding in the current word $x_t$ as well as the hidden state from the previous word, $h_{t-1}$, to produce the next hidden state, $h_t$.
#
# $$h_t = \text{RNN}(x_t, h_{t-1})$$
#
# Once we have our final hidden state, $h_T$, (from feeding in the last word in the sequence, $x_T$) we feed it through a linear layer, $f$, (also known as a fully connected layer), to receive our predicted sentiment, $\hat{y} = f(h_T)$.
#
# Below shows an example sentence, with the RNN predicting zero, which indicates a negative sentiment. The RNN is shown in orange and the linear layer shown in silver. Note that we use the same RNN for every word, i.e. it has the same parameters. The initial hidden state, $h_0$, is a tensor initialized to all zeros.
#
# ![](https://github.com/bentrevett/pytorch-sentiment-analysis/blob/master/assets/sentiment1.png?raw=1)
#
# **Note:** some layers and steps have been omitted from the diagram, but these will be explained later.

# %% [markdown]
# ## Preparing Data
#
# One of the main concepts of TorchText is the `Field`. These define how your data should be processed. In our sentiment classification task the data consists of both the raw string of the review and the sentiment, either "pos" or "neg".
#
# The parameters of a `Field` specify how the data should be processed.
#
# We use the `TEXT` field to define how the review should be processed, and the `LABEL` field to process the sentiment.
#
# Our `TEXT` field has `tokenize='spacy'` as an argument. This defines that the "tokenization" (the act of splitting the string into discrete "tokens") should be done using the [spaCy](https://spacy.io) tokenizer. If no `tokenize` argument is passed, the default is simply splitting the string on spaces. We also need to specify a `tokenizer_language` which tells torchtext which spaCy model to use. We use the `en_core_web_sm` model which has to be downloaded with `python -m spacy download en_core_web_sm` before you run this notebook!
#
# `LABEL` is defined by a `LabelField`, a special subset of the `Field` class specifically used for handling labels. We will explain the `dtype` argument later.
#
# For more on `Fields`, go [here](https://github.com/pytorch/text/blob/master/torchtext/data/field.py).
#
# We also set the random seeds for reproducibility.

# %%
# !pip install torchtext==0.4.0
# !pip install --upgrade gensim
# Out:
# Requirement already satisfied: torchtext==0.4.0 in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (4.66.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (2.31.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (2.1.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (1.25.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.4.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.4.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.4.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.4.0) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->torchtext==0.4.0) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->torchtext==0.4.0) (1.3.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.25.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)

# %%
import torch
from torchtext import data


from gensim.test.utils import common_texts
from gensim.models import Word2Vec
# word2vec
model = Word2Vec(sentences=common_texts, vector_size=100, window=5, min_count=1, workers=4)
model.save("word2vec.model")


SEED = 1234

torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

TEXT = data.Field(tokenize = 'spacy',
                  tokenizer_language = 'en_core_web_sm',
                  include_lengths = True,
                  pad_first=True)

LABEL = data.LabelField(dtype = torch.float)

# %% [markdown]
# Another handy feature of TorchText is that it has support for common datasets used in natural language processing (NLP).
#
# The following code automatically downloads the IMDb dataset and splits it into the canonical train/test splits as `torchtext.datasets` objects. It process the data using the `Fields` we have previously defined. The IMDb dataset consists of 50,000 movie reviews, each marked as being a positive or negative review.

# %%
from torchtext import datasets

train_data, test_data = datasets.IMDB.splits(TEXT, LABEL)

# %% [markdown]
# We can see how many examples are in each split by checking their length.

# %%
print(f'Number of training examples: {len(train_data)}')
print(f'Number of testing examples: {len(test_data)}')
# Out:
# Number of training examples: 25000
# Number of testing examples: 25000

# %% [markdown]
# We can also check an example.

# %%
print(vars(train_data.examples[0]))
# Out:
# {'text': ['One', 'does', "n't", 'get', 'to', 'enjoy', 'this', 'gem', ',', 'the', '1936', 'Invisible', 'Ray', ',', 'often', '.', 'But', 'no', 'can', 'forget', 'it', '.', 'The', 'story', 'is', 'elegant', '.', 'Karloff', ',', 'austere', 'and', 'embittered', 'in', 'his', 'Carpathian', 'mountain', 'retreat', ',', 'is', 'Janos', 'Rukh', ',', 'genius', 'science', 'who', 'reads', 'ancient', 'beams', 'of', 'light', 'to', 'ascertain', 'events', 'in', 'the', 'great', 'geological', 'past', '\x85', 'particularly', 'the', 'crash', 'of', 'a', 'potent', 'radioactive', 'meteor', 'in', 'Africa', '.', 'Joining', 'him', 'is', 'the', 'ever', '-', 'elegant', 'Lugosi', '(', 'as', 'a', 'rare', 'hero', ')', ',', 'who', 'studies', '"', 'astro', '-', 'chemistry', '.', '"', 'Frances', 'Drake', 'is', 'the', 'lovely', ',', 'underused', 'young', 'wife', ';', 'Frank', 'Lawton', 'the', 'romantic', 'temptation', ';', 'and', 'the', 'divine', 'Violet', 'Kemble', 'Cooper', 'is', 'Mother', 'Rukh', ',', 'in', 'a', 'performance', 'worthy', 'of', 'Maria', 'Ospenskya.<br', '/><br', '/>The', 'story', 'moves', 'swiftly', 'in', 'bold', 'episodes', ',', 'with', 'special', 'effects', 'that', 'are', 'still', 'handsome', '.', 'It', 'also', 'contains', 'some', 'wonderful', 'lines', '.', 'One', 'Rukh', 'restores', 'his', 'mother', "'s", 'sight', ',', 'he', 'asks', ',', '"', 'Mother', ',', 'can', 'you', 'see', ',', 'can', 'you', 'see', '?', '"', '"', 'Yes', ',', 'I', 'can', 'see', '\x85', 'more', 'clearly', 'than', 'ever', '.', 'And', 'what', 'I', 'see', 'frightens', 'me', '.', '"', 'Even', 'better', 'when', 'mother', 'Rukh', 'says', ',', '"', 'He', 'broke', 'the', 'first', 'law', 'of', 'science', '.', '"', 'I', 'am', 'not', 'alone', 'among', 'my', 'acquaintance', 'in', 'having', 'puzzled', 'for', 'many', 'many', 'years', 'exactly', 'what', 'this', 'first', 'law', 'of', 'science', 'is.<br', '/><br', '/>This', 'movie', 'is', 'definitely', 'desert', 'island', 'material', '.'], 'label': 'pos'}

# %% [markdown]
# The IMDb dataset only has train/test splits, so we need to create a validation set. We can do this with the `.split()` method.
#
# By default this splits 70/30, however by passing a `split_ratio` argument, we can change the ratio of the split, i.e. a `split_ratio` of 0.8 would mean 80% of the examples make up the training set and 20% make up the validation set.
#
# We also pass our random seed to the `random_state` argument, ensuring that we get the same train/validation split each time.

# %%
import random

train_data, valid_data = train_data.split(split_ratio = 0.8, random_state = random.seed(SEED))

# %% [markdown]
# Again, we'll view how many examples are in each split.

# %%
print(f'Number of training examples: {len(train_data)}')
print(f'Number of validation examples: {len(valid_data)}')
print(f'Number of testing examples: {len(test_data)}')
# Out:
# Number of training examples: 20000
# Number of validation examples: 5000
# Number of testing examples: 25000

# %% [markdown]
# Next, we have to build a _vocabulary_. This is a effectively a look up table where every unique word in your data set has a corresponding _index_ (an integer).
#
# We do this as our machine learning model cannot operate on strings, only numbers. Each _index_ is used to construct a _one-hot_ vector for each word. A one-hot vector is a vector where all of the elements are 0, except one, which is 1, and dimensionality is the total number of unique words in your vocabulary, commonly denoted by $V$.
#
# ![](https://github.com/bentrevett/pytorch-sentiment-analysis/blob/master/assets/sentiment5.png?raw=1)
#
# The number of unique words in our training set is over 100,000, which means that our one-hot vectors will have over 100,000 dimensions! This will make training slow and possibly won't fit onto your GPU (if you're using one).
#
# There are two ways effectively cut down our vocabulary, we can either only take the top $n$ most common words or ignore words that appear less than $m$ times. We'll do the former, only keeping the top 25,000 words.
#
# What do we do with words that appear in examples but we have cut from the vocabulary? We replace them with a special _unknown_ or `<unk>` token. For example, if the sentence was "This film is great and I love it" but the word "love" was not in the vocabulary, it would become "This film is great and I `<unk>` it".
#
# The following builds the vocabulary, only keeping the most common `max_size` tokens.

# %%
# print number of unique words

TEXT.build_vocab(train_data)
LABEL.build_vocab(train_data)
print(len(TEXT.vocab))
print(len(LABEL.vocab))

print(LABEL.vocab.stoi)
# here I see that hte length of the label vocabulary is only 2 long?
# This is because we have postive and negative only
print(LABEL.vocab.itos) # wtf is itos..,
# Out:
# 108104
# 2
# defaultdict(None, {'neg': 0, 'pos': 1})
# ['neg', 'pos']

# %%
MAX_VOCAB_SIZE = 25_000

# MAX_VOCAB_SIZE = 0

TEXT.build_vocab(train_data, max_size = MAX_VOCAB_SIZE)
LABEL.build_vocab(train_data)

print(len(TEXT.vocab)) # why is this MAX_VOCAB_SIZE +2 ?  <unk> and <pad>
print(len(LABEL.vocab))
# Out:
# 25002
# 2

# %% [markdown]
# Why do we only build the vocabulary on the training set? When testing any machine learning system you do not want to look at the test set in any way. We do not include the validation set as we want it to reflect the test set as much as possible.

# %%
print(f"Unique tokens in TEXT vocabulary: {len(TEXT.vocab)}")
print(f"Unique tokens in LABEL vocabulary: {len(LABEL.vocab)}")
# Out:
# Unique tokens in TEXT vocabulary: 25002
# Unique tokens in LABEL vocabulary: 2

# %% [markdown]
# Why is the vocab size 25002 and not 25000? One of the addition tokens is the `<unk>` token and the other is a `<pad>` token.
#
# When we feed sentences into our model, we feed a _batch_ of them at a time, i.e. more than one at a time, and all sentences in the batch need to be the same size. Thus, to ensure each sentence in the batch is the same size, any shorter than the longest within the batch are padded.
#
# ![](https://github.com/bentrevett/pytorch-sentiment-analysis/blob/master/assets/sentiment6.png?raw=1)
#
# We can also view the most common words in the vocabulary and their frequencies.

# %%
print(TEXT.vocab.freqs.most_common(20))
# Out:
# [('the', 231536), (',', 219922), ('.', 188609), ('and', 124957), ('a', 124524), ('of', 114906), ('to', 106799), ('is', 86737), ('in', 69981), ('I', 61797), ('it', 60977), ('that', 55993), ('"', 50690), ("'s", 49400), ('this', 48226), ('-', 42605), ('/><br', 40906), ('was', 40120), ('as', 34996), ('with', 34161)]

# %% [markdown]
# We can also see the vocabulary directly using either the `stoi` (**s**tring **to** **i**nt) or `itos` (**i**nt **to**  **s**tring) method.

# %%
print(TEXT.vocab.itos[:10])
# Out:
# ['<unk>', '<pad>', 'the', ',', '.', 'and', 'a', 'of', 'to', 'is']

# %% [markdown]
# We can also check the labels, ensuring 0 is for negative and 1 is for positive.

# %%
print(LABEL.vocab.stoi)
# Out:
# defaultdict(None, {'neg': 0, 'pos': 1})

# %%
TEXT.__dict__
# Out:
# {'sequential': True,
#  'use_vocab': True,
#  'init_token': None,
#  'eos_token': None,
#  'unk_token': '<unk>',
#  'fix_length': None,
#  'dtype': torch.int64,
#  'preprocessing': None,
#  'postprocessing': None,
#  'lower': False,
#  'tokenizer_args': ('spacy', 'en_core_web_sm'),
#  'tokenize': functools.partial(<function _spacy_tokenize at 0x7c2084b8c550>, spacy=<spacy.lang.en.English object at 0x7c20639f3070>),
#  'include_lengths': True,
#  'batch_first': False,
#  'pad_token': '<pad>',
#  'pad_first': True,
#  'truncate_first': False,
#  'stop_words': None,
#  'is_target': False,
#  'vocab': <torchtext.vocab.Vocab at 0x7c213ea1d240>}

# %% [markdown]
# The final step of preparing the data is creating the iterators. We iterate over these in the training/evaluation loop, and they return a batch of examples (indexed and converted into tensors) at each iteration.
#
# We'll use a `BucketIterator` which is a special type of iterator that will return a batch of examples where each example is of a similar length, minimizing the amount of padding per example.
#
# We also want to place the tensors returned by the iterator on the GPU (if you're using one). PyTorch handles this using `torch.device`, we then pass this device to the iterator.

# %%
BATCH_SIZE = 64

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_iterator, valid_iterator, test_iterator = data.BucketIterator.splits(
    (train_data, valid_data, test_data),
    batch_size = BATCH_SIZE,
    sort_within_batch = True,
    device = device)

# %% [markdown]
# ## Build the Model
#
# The next stage is building the model that we'll eventually train and evaluate.
#
# There is a small amount of boilerplate code when creating models in PyTorch, note how our `RNN` class is a sub-class of `nn.Module` and the use of `super`.
#
# Within the `__init__` we define the _layers_ of the module. Our three layers are an _embedding_ layer, our RNN, and a _linear_ layer. All layers have their parameters initialized to random values, unless explicitly specified.
#
# The embedding layer is used to transform our sparse one-hot vector (sparse as most of the elements are 0) into a dense embedding vector (dense as the dimensionality is a lot smaller and all the elements are real numbers). This embedding layer is simply a single fully connected layer. As well as reducing the dimensionality of the input to the RNN, there is the theory that words which have similar impact on the sentiment of the review are mapped close together in this dense vector space. For more information about word embeddings, see [here](https://monkeylearn.com/blog/word-embeddings-transform-text-numbers/).
#
# The RNN layer is our RNN which takes in our dense vector and the previous hidden state $h_{t-1}$, which it uses to calculate the next hidden state, $h_t$.
#
# ![](https://github.com/bentrevett/pytorch-sentiment-analysis/blob/master/assets/sentiment7.png?raw=1)
#
# Finally, the linear layer takes the final hidden state and feeds it through a fully connected layer, $f(h_T)$, transforming it to the correct output dimension.
#
# The `forward` method is called when we feed examples into our model.
#
# Each batch, `text`, is a tensor of size _**[sentence length, batch size]**_. That is a batch of sentences, each having each word converted into a one-hot vector.
#
# You may notice that this tensor should have another dimension due to the one-hot vectors, however PyTorch conveniently stores a one-hot vector as it's index value, i.e. the tensor representing a sentence is just a tensor of the indexes for each token in that sentence. The act of converting a list of tokens into a list of indexes is commonly called *numericalizing*.
#
# The input batch is then passed through the embedding layer to get `embedded`, which gives us a dense vector representation of our sentences. `embedded` is a tensor of size _**[sentence length, batch size, embedding dim]**_.
#
# `embedded` is then fed into the RNN. In some frameworks you must feed the initial hidden state, $h_0$, into the RNN, however in PyTorch, if no initial hidden state is passed as an argument it defaults to a tensor of all zeros.
#
# The RNN returns 2 tensors, `output` of size _**[sentence length, batch size, hidden dim]**_ and `hidden` of size _**[1, batch size, hidden dim]**_. `output` is the concatenation of the hidden state from every time step, whereas `hidden` is simply the final hidden state. We verify this using the `assert` statement. Note the `squeeze` method, which is used to remove a dimension of size 1.
#
# Finally, we feed the last hidden state, `hidden`, through the linear layer, `fc`, to produce a prediction.

# %%
import torch.nn as nn
import torch.nn.functional as F


class RNN(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim):
        super().__init__()


        self.embedding = nn.Embedding(input_dim, embedding_dim)

        # Set up the RNN layer
        self.rnn = nn.RNN(embedding_dim, hidden_dim)

        # Set up the fully connected layer that outputs the prediction
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, text, text_lengths=None):

        # Embedding layer
        embedded = self.embedding(text)

        # RNN layer
        output, hidden = self.rnn(embedded)


        # Fully connected layer
        return self.fc(hidden.squeeze(0))


# dynamic FFN
class FFN(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dims, output_dim):
        super().__init__()

        self.embedding = nn.Embedding(input_dim, embedding_dim)

        # Dynamically create the fully connected layers based on hidden_dims
        layers = []
        in_features = embedding_dim
        for hidden_dim in hidden_dims:
            layers.append(nn.Linear(in_features, hidden_dim))
            in_features = hidden_dim  # Update in_features for the next layer

        self.fc_layers = nn.ModuleList(layers)
        self.output_layer = nn.Linear(in_features, output_dim)

    def forward(self, text, text_lengths=None):
        # Embedding layer
        embedded = self.embedding(text)

        # Aggregate embeddings (mean over sequence dimension)
        output = embedded.mean(dim=0)

        # Dynamically apply each fully connected layer with ReLU activation
        for layer in self.fc_layers:
            output = F.relu(layer(output))

        # Output layer
        return self.output_layer(output)


# CNN model (using three feature maps with the sizes are 1, 2, and 3)
class CNN(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim_1, output_dim):
        super().__init__()

        self.embedding = nn.Embedding(input_dim, embedding_dim)

        # Set up the CNN layers
        self.cnn1 = nn.Conv1d(embedding_dim, hidden_dim_1, 1)
        self.cnn2 = nn.Conv1d(embedding_dim, hidden_dim_1, 2)
        self.cnn3 = nn.Conv1d(embedding_dim, hidden_dim_1, 3)

        # Set up the fully connected layer that outputs the prediction
        self.fc = nn.Linear(hidden_dim_1 * 3, output_dim)


    def forward(self, text, text_lengths=None):
        # text = [sent len, batch size]

        # Embedding layer
        embedded = self.embedding(text)

        # why do I need to do this?
        embedded = embedded.permute(1, 2, 0)
        # embedded = [batch size, emb dim, sent len]

        # CNN layer
        output1 = F.relu(self.cnn1(embedded))
        output2 = F.relu(self.cnn2(embedded))
        output3 = F.relu(self.cnn3(embedded))

        # Max pooling
        output1 = F.max_pool1d(output1, output1.shape[2]).squeeze(2)
        output2 = F.max_pool1d(output2, output2.shape[2]).squeeze(2)
        output3 = F.max_pool1d(output3, output3.shape[2]).squeeze(2)

        # Fully connected layer
        return self.fc(torch.cat((output1, output2, output3), dim=1))


class LSTM(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim, device=device):
        super().__init__()

        # Store the device in the model
        self.device = device

        self.embedding = nn.Embedding(input_dim, embedding_dim)

        self.lstm = nn.LSTM(embedding_dim, hidden_dim, bidirectional=False)

        self.linear = nn.Linear(hidden_dim, output_dim)

        # Move the model itself to the specified device (GPU or CPU) couldn't get it to work otherwise...
        self.to(device)

    def forward(self, text, text_lengths=None):
        # Ensure inputs are on the correct device
        text = text.to(self.device)
        if text_lengths is not None:
            text_lengths = text_lengths.to('cpu').long()  # text_lengths must be on CPU for pack_padded_sequence

        embedded = self.embedding(text)

        # When using pack_padded_sequence, make sure to sort or enforce_sorted=False
        if text_lengths is not None:
            packed_embedded = nn.utils.rnn.pack_padded_sequence(embedded, text_lengths, enforce_sorted=False)
            packed_output, (hidden, cell) = self.lstm(packed_embedded)
            output, output_lengths = nn.utils.rnn.pad_packed_sequence(packed_output)
        else:
            output, (hidden, cell) = self.lstm(embedded)

        # If you want to use only the last hidden state:
        out = self.linear(hidden[-1, :, :])

        return out

class BiLSTM(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim, device=device):
        super().__init__()

        # Store the device in the model
        self.device = device

        self.embedding = nn.Embedding(input_dim, embedding_dim)

        self.lstm = nn.LSTM(embedding_dim, hidden_dim, bidirectional=True)

        self.linear = nn.Linear(hidden_dim, output_dim)

        # Move the model itself to the specified device (GPU or CPU) couldn't get it to work otherwise...
        self.to(device)

    def forward(self, text, text_lengths=None):
        # Ensure inputs are on the correct device
        text = text.to(self.device)
        if text_lengths is not None:
            text_lengths = text_lengths.to('cpu').long()  # text_lengths must be on CPU for pack_padded_sequence

        embedded = self.embedding(text)

        # When using pack_padded_sequence, make sure to sort or enforce_sorted=False
        if text_lengths is not None:
            packed_embedded = nn.utils.rnn.pack_padded_sequence(embedded, text_lengths, enforce_sorted=False)
            packed_output, (hidden, cell) = self.lstm(packed_embedded)
            output, output_lengths = nn.utils.rnn.pad_packed_sequence(packed_output)
        else:
            output, (hidden, cell) = self.lstm(embedded)

        # If you want to use only the last hidden state:
        out = self.linear(hidden[-1, :, :])

        return out

# %% [markdown]
# We now create an instance of our RNN class.
#
# The input dimension is the dimension of the one-hot vectors, which is equal to the vocabulary size.
#
# The embedding dimension is the size of the dense word vectors. This is usually around 50-250 dimensions, but depends on the size of the vocabulary.
#
# The hidden dimension is the size of the hidden states. This is usually around 100-500 dimensions, but also depends on factors such as on the vocabulary size, the size of the dense vectors and the complexity of the task.
#
# The output dimension is usually the number of classes, however in the case of only 2 classes the output value is between 0 and 1 and thus can be 1-dimensional, i.e. a single scalar real number.

# %%
INPUT_DIM = len(TEXT.vocab)
# EMBEDDING_DIM = 100
HIDDEN_DIM = 256
OUTPUT_DIM = 1

# model = RNN(INPUT_DIM, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM)

# %% [markdown]
# Let's also create a function that will tell us how many trainable parameters our model has so we can compare the number of parameters across different models.

# %%
# def count_parameters(model):
#     return sum(p.numel() for p in model.parameters() if p.requires_grad)

# print(f'The model has {count_parameters(model):,} trainable parameters')

# %% [markdown]
# ## Train the Model

# %% [markdown]
# Now we'll set up the training and then train the model.
#
# First, we'll create an optimizer. This is the algorithm we use to update the parameters of the module. Here, we'll use _stochastic gradient descent_ (SGD). The first argument is the parameters will be updated by the optimizer, the second is the learning rate, i.e. how much we'll change the parameters by when we do a parameter update.

# %%
# import torch.optim as optim
# optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %% [markdown]
# Next, we'll define our loss function. In PyTorch this is commonly called a criterion.
#
# The loss function here is _binary cross entropy with logits_.
#
# Our model currently outputs an unbound real number. As our labels are either 0 or 1, we want to restrict the predictions to a number between 0 and 1. We do this using the _sigmoid_ or _logit_ functions.
#
# We then use this this bound scalar to calculate the loss using binary cross entropy.
#
# The `BCEWithLogitsLoss` criterion carries out both the sigmoid and the binary cross entropy steps.

# %%
# criterion = nn.BCEWithLogitsLoss()

# %% [markdown]
# Using `.to`, we can place the model and the criterion on the GPU (if we have one).

# %%
# model = model.to(device)
# criterion = criterion.to(device)

# %% [markdown]
# Our criterion function calculates the loss, however we have to write our function to calculate the accuracy.
#
# This function first feeds the predictions through a sigmoid layer, squashing the values between 0 and 1, we then round them to the nearest integer. This rounds any value greater than 0.5 to 1 (a positive sentiment) and the rest to 0 (a negative sentiment).
#
# We then calculate how many rounded predictions equal the actual labels and average it across the batch.

# %%
def binary_accuracy(preds, y):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """

    #round predictions to the closest integer
    rounded_preds = torch.round(torch.sigmoid(preds))
    correct = (rounded_preds == y).float() #convert into float for division
    acc = correct.sum() / len(correct)
    return acc

# %% [markdown]
# The `train` function iterates over all examples, one batch at a time.
#
# `model.train()` is used to put the model in "training mode", which turns on _dropout_ and _batch normalization_. Although we aren't using them in this model, it's good practice to include it.
#
# For each batch, we first zero the gradients. Each parameter in a model has a `grad` attribute which stores the gradient calculated by the `criterion`. PyTorch does not automatically remove (or "zero") the gradients calculated from the last gradient calculation, so they must be manually zeroed.
#
# We then feed the batch of sentences, `batch.text`, into the model. Note, you do not need to do `model.forward(batch.text)`, simply calling the model works. The `squeeze` is needed as the predictions are initially size _**[batch size, 1]**_, and we need to remove the dimension of size 1 as PyTorch expects the predictions input to our criterion function to be of size _**[batch size]**_.
#
# The loss and accuracy are then calculated using our predictions and the labels, `batch.label`, with the loss being averaged over all examples in the batch.
#
# We calculate the gradient of each parameter with `loss.backward()`, and then update the parameters using the gradients and optimizer algorithm with `optimizer.step()`.
#
# The loss and accuracy is accumulated across the epoch, the `.item()` method is used to extract a scalar from a tensor which only contains a single value.
#
# Finally, we return the loss and accuracy, averaged across the epoch. The `len` of an iterator is the number of batches in the iterator.
#
# You may recall when initializing the `LABEL` field, we set `dtype=torch.float`. This is because TorchText sets tensors to be `LongTensor`s by default, however our criterion expects both inputs to be `FloatTensor`s. Setting the `dtype` to be `torch.float`, did this for us. The alternative method of doing this would be to do the conversion inside the `train` function by passing `batch.label.float()` instad of `batch.label` to the criterion.

# %%
def train(model, iterator, optimizer, criterion):

    epoch_loss = 0
    epoch_acc = 0

    model.train()

    for batch in iterator:

        optimizer.zero_grad()

        text, text_lengths = batch.text

        predictions = model(text, text_lengths).squeeze(1)

        loss = criterion(predictions, batch.label)

        acc = binary_accuracy(predictions, batch.label)

        loss.backward()

        optimizer.step()

        epoch_loss += loss.item()
        epoch_acc += acc.item()

    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %% [markdown]
# `evaluate` is similar to `train`, with a few modifications as you don't want to update the parameters when evaluating.
#
# `model.eval()` puts the model in "evaluation mode", this turns off _dropout_ and _batch normalization_. Again, we are not using them in this model, but it is good practice to include them.
#
# No gradients are calculated on PyTorch operations inside the `with no_grad()` block. This causes less memory to be used and speeds up computation.
#
# The rest of the function is the same as `train`, with the removal of `optimizer.zero_grad()`, `loss.backward()` and `optimizer.step()`, as we do not update the model's parameters when evaluating.

# %%
def evaluate(model, iterator, criterion):

    epoch_loss = 0
    epoch_acc = 0

    model.eval()

    with torch.no_grad():

        for batch in iterator:
            text, text_lengths = batch.text

            predictions = model(text, text_lengths).squeeze(1)

            loss = criterion(predictions, batch.label)

            acc = binary_accuracy(predictions, batch.label)

            epoch_loss += loss.item()
            epoch_acc += acc.item()

    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %% [markdown]
# We'll also create a function to tell us how long an epoch takes to compare training times between models.

# %%
import time

def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
def trainer(name, model, lr, N_EPOCHS):
  losses = []
  best_valid_loss = float('inf')
  for epoch in range(N_EPOCHS):

      start_time = time.time()

      train_loss, train_acc = train(model, train_iterator, optimizer, criterion)
      losses.append(train_loss)
      valid_loss, valid_acc = evaluate(model, valid_iterator, criterion)

      end_time = time.time()

      epoch_mins, epoch_secs = epoch_time(start_time, end_time)

      if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        model_file_name = f"model_{name}_best_valid_loss.pt"

        torch.save(model.state_dict(), model_file_name)


      print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
      print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
      print(f'\t Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc*100:.2f}%')

  print("done", name)
  tot_save_name = f"total_model_{name}.pt"
  torch.save(model, tot_save_name)
  print("saved", tot_save_name)

  lossesDict[name] = losses

# %% [markdown]
# We then train the model through multiple epochs, an epoch being a complete pass through all examples in the training and validation sets.
#
# At each epoch, if the validation loss is the best we have seen so far, we'll save the parameters of the model and then after training has finished we'll use that model on the test set.

# %%
# Create the model

# • One-layer feed forward neural network, hidden dimension is 500.
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 100
HIDDEN_DIMS = [500]
OUTPUT_DIM = 1
model1 = FFN(INPUT_DIM, EMBEDDING_DIM, HIDDEN_DIMS, OUTPUT_DIM)


# • Two-layer feed forward neural network, hidden dimensions are 500 and 300.
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 100
HIDDEN_DIMS = [500, 300]
OUTPUT_DIM = 1
model2 = FFN(INPUT_DIM, EMBEDDING_DIM, HIDDEN_DIMS, OUTPUT_DIM)

# • Three-layer feed forward neural network, hidden dimensions are 500, 300, and 200
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 100
HIDDEN_DIMS = [500, 300, 200]
OUTPUT_DIM = 1
model3 = FFN(INPUT_DIM, EMBEDDING_DIM, HIDDEN_DIMS, OUTPUT_DIM)

# CNN
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 100
HIDDEN_DIM_1 = 500
OUTPUT_DIM = 1
model4 = CNN(INPUT_DIM, EMBEDDING_DIM, HIDDEN_DIM_1, OUTPUT_DIM)

# • LSTM neural network.<c
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 100
HIDDEN_DIM = 300
OUTPUT_DIM = 1

model5 = LSTM(INPUT_DIM, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM)

# • Bi-LSTM neural network.<c
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 100
HIDDEN_DIM = 300
OUTPUT_DIM = 1

model6 = BiLSTM(INPUT_DIM, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM)

# %%
N_EPOCHS = 50
lr = 1e-3
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
models = {"FFN1": model1, "FFN2": model2, "FFN3": model3, "CNN": model4, "LSTM": model5, "BiLSTM": model6}
lossesDict = {}
# global lossesDict

for name, model in models.items():
  import torch.optim as optim
  optimizer = optim.Adam(model.parameters(), lr=lr)

  model.to(device)

  criterion = nn.BCEWithLogitsLoss()
  criterion = criterion.to(device)

  trainer(name,model, lr, N_EPOCHS)
# Out:
# Epoch: 01 | Epoch Time: 0m 3s
# 	Train Loss: 0.539 | Train Acc: 72.07%
# 	 Val. Loss: 0.421 |  Val. Acc: 81.51%
# Epoch: 02 | Epoch Time: 0m 2s
# 	Train Loss: 0.328 | Train Acc: 85.80%
# 	 Val. Loss: 0.341 |  Val. Acc: 86.16%
# Epoch: 03 | Epoch Time: 0m 2s
# 	Train Loss: 0.250 | Train Acc: 90.10%
# 	 Val. Loss: 0.337 |  Val. Acc: 86.37%
# Epoch: 04 | Epoch Time: 0m 2s
# 	Train Loss: 0.188 | Train Acc: 92.89%
# 	 Val. Loss: 0.320 |  Val. Acc: 87.78%
# Epoch: 05 | Epoch Time: 0m 2s
# 	Train Loss: 0.151 | Train Acc: 94.74%
# 	 Val. Loss: 0.424 |  Val. Acc: 85.23%
# Epoch: 06 | Epoch Time: 0m 2s
# 	Train Loss: 0.119 | Train Acc: 96.13%
# 	 Val. Loss: 0.436 |  Val. Acc: 85.74%
# Epoch: 07 | Epoch Time: 0m 2s
# 	Train Loss: 0.096 | Train Acc: 97.27%
# 	 Val. Loss: 0.428 |  Val. Acc: 86.79%
# Epoch: 08 | Epoch Time: 0m 2s
# 	Train Loss: 0.082 | Train Acc: 98.13%
# 	 Val. Loss: 0.411 |  Val. Acc: 87.95%
# Epoch: 09 | Epoch Time: 0m 2s
# 	Train Loss: 0.066 | Train Acc: 98.67%
# 	 Val. Loss: 0.454 |  Val. Acc: 87.46%
# Epoch: 10 | Epoch Time: 0m 2s
# 	Train Loss: 0.046 | Train Acc: 99.13%
# 	 Val. Loss: 0.504 |  Val. Acc: 87.40%
# Epoch: 11 | Epoch Time: 0m 2s
# 	Train Loss: 0.053 | Train Acc: 98.94%
# 	 Val. Loss: 0.760 |  Val. Acc: 83.76%
# Epoch: 12 | Epoch Time: 0m 2s
# 	Train Loss: 0.048 | Train Acc: 99.16%
# 	 Val. Loss: 0.539 |  Val. Acc: 87.66%
# Epoch: 13 | Epoch Time: 0m 2s
# 	Train Loss: 0.026 | Train Acc: 99.45%
# 	 Val. Loss: 0.564 |  Val. Acc: 87.76%
# Epoch: 14 | Epoch Time: 0m 2s
# 	Train Loss: 0.036 | Train Acc: 99.22%
# 	 Val. Loss: 0.681 |  Val. Acc: 86.29%
# Epoch: 15 | Epoch Time: 0m 2s
# 	Train Loss: 0.017 | Train Acc: 99.64%
# 	 Val. Loss: 0.617 |  Val. Acc: 87.88%
# Epoch: 16 | Epoch Time: 0m 2s
# 	Train Loss: 0.029 | Train Acc: 99.61%
# 	 Val. Loss: 0.676 |  Val. Acc: 87.05%
# Epoch: 17 | Epoch Time: 0m 2s
# 	Train Loss: 0.045 | Train Acc: 99.52%
# 	 Val. Loss: 0.664 |  Val. Acc: 87.90%
# Epoch: 18 | Epoch Time: 0m 2s
# 	Train Loss: 0.010 | Train Acc: 99.63%
# 	 Val. Loss: 0.879 |  Val. Acc: 85.42%
# Epoch: 19 | Epoch Time: 0m 2s
# 	Train Loss: 0.040 | Train Acc: 99.28%
# 	 Val. Loss: 0.709 |  Val. Acc: 88.01%
# Epoch: 20 | Epoch Time: 0m 2s
# 	Train Loss: 0.043 | Train Acc: 99.50%
# 	 Val. Loss: 0.726 |  Val. Acc: 87.90%
# Epoch: 21 | Epoch Time: 0m 2s
# 	Train Loss: 0.003 | Train Acc: 99.98%
# 	 Val. Loss: 0.733 |  Val. Acc: 87.80%
# Epoch: 22 | Epoch Time: 0m 2s
# 	Train Loss: 0.019 | Train Acc: 99.67%
# 	 Val. Loss: 1.054 |  Val. Acc: 84.79%
# Epoch: 23 | Epoch Time: 0m 2s
# 	Train Loss: 0.054 | Train Acc: 99.50%
# 	 Val. Loss: 0.791 |  Val. Acc: 87.54%
# Epoch: 24 | Epoch Time: 0m 2s
# 	Train Loss: 0.039 | Train Acc: 99.23%
# 	 Val. Loss: 0.952 |  Val. Acc: 85.62%
# Epoch: 25 | Epoch Time: 0m 2s
# 	Train Loss: 0.017 | Train Acc: 99.74%
# 	 Val. Loss: 0.796 |  Val. Acc: 87.68%
# Epoch: 26 | Epoch Time: 0m 2s
# 	Train Loss: 0.026 | Train Acc: 99.71%
# 	 Val. Loss: 0.795 |  Val. Acc: 87.76%
# Epoch: 27 | Epoch Time: 0m 2s
# 	Train Loss: 0.002 | Train Acc: 99.98%
# 	 Val. Loss: 0.805 |  Val. Acc: 87.70%
# Epoch: 28 | Epoch Time: 0m 2s
# 	Train Loss: 0.001 | Train Acc: 100.00%
# 	 Val. Loss: 0.818 |  Val. Acc: 87.66%
# Epoch: 29 | Epoch Time: 0m 2s
# 	Train Loss: 0.001 | Train Acc: 100.00%
# 	 Val. Loss: 0.829 |  Val. Acc: 87.76%
# Epoch: 30 | Epoch Time: 0m 2s
# 	Train Loss: 0.001 | Train Acc: 99.98%
# 	 Val. Loss: 0.861 |  Val. Acc: 87.70%
# Epoch: 31 | Epoch Time: 0m 2s
# 	Train Loss: 0.004 | Train Acc: 99.84%
# 	 Val. Loss: 0.921 |  Val. Acc: 87.28%
# Epoch: 32 | Epoch Time: 0m 2s
# 	Train Loss: 0.018 | Train Acc: 99.70%
# 	 Val. Loss: 1.114 |  Val. Acc: 85.30%
# Epoch: 33 | Epoch Time: 0m 2s
# 	Train Loss: 0.105 | Train Acc: 98.84%
# 	 Val. Loss: 0.981 |  Val. Acc: 86.93%
# Epoch: 34 | Epoch Time: 0m 2s
# 	Train Loss: 0.002 | Train Acc: 99.96%
# 	 Val. Loss: 0.898 |  Val. Acc: 87.95%
# Epoch: 35 | Epoch Time: 0m 2s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.903 |  Val. Acc: 87.88%
# Epoch: 36 | Epoch Time: 0m 2s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.908 |  Val. Acc: 87.97%
# Epoch: 37 | Epoch Time: 0m 2s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.915 |  Val. Acc: 87.95%
# Epoch: 38 | Epoch Time: 0m 2s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.923 |  Val. Acc: 87.95%
# Epoch: 39 | Epoch Time: 0m 2s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.934 |  Val. Acc: 87.84%
# Epoch: 40 | Epoch Time: 0m 2s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.940 |  Val. Acc: 87.84%
# Epoch: 41 | Epoch Time: 0m 2s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.950 |  Val. Acc: 87.84%
# Epoch: 42 | Epoch Time: 0m 2s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.961 |  Val. Acc: 87.94%
# Epoch: 43 | Epoch Time: 0m 2s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.973 |  Val. Acc: 87.86%
# Epoch: 44 | Epoch Time: 0m 2s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.988 |  Val. Acc: 87.68%
# Epoch: 45 | Epoch Time: 0m 2s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.996 |  Val. Acc: 87.90%
# Epoch: 46 | Epoch Time: 0m 2s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 1.008 |  Val. Acc: 87.88%
# Epoch: 47 | Epoch Time: 0m 2s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 1.028 |  Val. Acc: 87.80%
# Epoch: 48 | Epoch Time: 0m 2s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 1.030 |  Val. Acc: 87.82%
# Epoch: 49 | Epoch Time: 0m 2s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 1.074 |  Val. Acc: 87.66%
# Epoch: 50 | Epoch Time: 0m 2s
# 	Train Loss: 0.007 | Train Acc: 99.83%
# 	 Val. Loss: 1.087 |  Val. Acc: 87.86%
# done FFN1
# saved total_model_FFN1.pt
# Epoch: 01 | Epoch Time: 0m 2s
# 	Train Loss: 0.519 | Train Acc: 74.01%
# 	 Val. Loss: 0.628 |  Val. Acc: 68.69%
# Epoch: 02 | Epoch Time: 0m 2s
# 	Train Loss: 0.348 | Train Acc: 85.15%
# 	 Val. Loss: 0.426 |  Val. Acc: 81.53%
# Epoch: 03 | Epoch Time: 0m 2s
# 	Train Loss: 0.261 | Train Acc: 90.07%
# 	 Val. Loss: 0.328 |  Val. Acc: 86.95%
# Epoch: 04 | Epoch Time: 0m 2s
# 	Train Loss: 0.204 | Train Acc: 92.25%
# 	 Val. Loss: 0.352 |  Val. Acc: 86.65%
# Epoch: 05 | Epoch Time: 0m 2s
# 	Train Loss: 0.149 | Train Acc: 94.70%
# 	 Val. Loss: 0.345 |  Val. Acc: 87.95%
# Epoch: 06 | Epoch Time: 0m 2s
# 	Train Loss: 0.106 | Train Acc: 96.55%
# 	 Val. Loss: 0.452 |  Val. Acc: 86.12%
# Epoch: 07 | Epoch Time: 0m 2s
# 	Train Loss: 0.113 | Train Acc: 96.62%
# 	 Val. Loss: 0.486 |  Val. Acc: 87.18%
# Epoch: 08 | Epoch Time: 0m 2s
# 	Train Loss: 0.077 | Train Acc: 97.67%
# 	 Val. Loss: 0.507 |  Val. Acc: 87.70%
# Epoch: 09 | Epoch Time: 0m 2s
# 	Train Loss: 0.042 | Train Acc: 98.76%
# 	 Val. Loss: 0.563 |  Val. Acc: 87.80%
# Epoch: 10 | Epoch Time: 0m 2s
# 	Train Loss: 0.050 | Train Acc: 98.55%
# 	 Val. Loss: 0.620 |  Val. Acc: 87.64%
# Epoch: 11 | Epoch Time: 0m 2s
# 	Train Loss: 0.019 | Train Acc: 99.43%
# 	 Val. Loss: 0.702 |  Val. Acc: 87.82%
# Epoch: 12 | Epoch Time: 0m 2s
# 	Train Loss: 0.033 | Train Acc: 99.14%
# 	 Val. Loss: 0.749 |  Val. Acc: 87.70%
# Epoch: 13 | Epoch Time: 0m 2s
# 	Train Loss: 0.019 | Train Acc: 99.16%
# 	 Val. Loss: 1.292 |  Val. Acc: 83.47%
# Epoch: 14 | Epoch Time: 0m 2s
# 	Train Loss: 0.015 | Train Acc: 99.34%
# 	 Val. Loss: 0.843 |  Val. Acc: 87.38%
# Epoch: 15 | Epoch Time: 0m 2s
# 	Train Loss: 0.011 | Train Acc: 99.63%
# 	 Val. Loss: 0.934 |  Val. Acc: 87.54%
# Epoch: 16 | Epoch Time: 0m 2s
# 	Train Loss: 0.029 | Train Acc: 98.88%
# 	 Val. Loss: 0.827 |  Val. Acc: 86.95%
# Epoch: 17 | Epoch Time: 0m 2s
# 	Train Loss: 0.027 | Train Acc: 98.98%
# 	 Val. Loss: 0.900 |  Val. Acc: 87.42%
# Epoch: 18 | Epoch Time: 0m 2s
# 	Train Loss: 0.031 | Train Acc: 98.91%
# 	 Val. Loss: 0.829 |  Val. Acc: 87.01%
# Epoch: 19 | Epoch Time: 0m 2s
# 	Train Loss: 0.008 | Train Acc: 99.74%
# 	 Val. Loss: 1.003 |  Val. Acc: 87.42%
# Epoch: 20 | Epoch Time: 0m 2s
# 	Train Loss: 0.050 | Train Acc: 98.87%
# 	 Val. Loss: 0.968 |  Val. Acc: 86.97%
# Epoch: 21 | Epoch Time: 0m 2s
# 	Train Loss: 0.022 | Train Acc: 99.48%
# 	 Val. Loss: 0.982 |  Val. Acc: 87.66%
# Epoch: 22 | Epoch Time: 0m 2s
# 	Train Loss: 0.028 | Train Acc: 99.22%
# 	 Val. Loss: 0.989 |  Val. Acc: 87.64%
# Epoch: 23 | Epoch Time: 0m 2s
# 	Train Loss: 0.012 | Train Acc: 99.57%
# 	 Val. Loss: 1.203 |  Val. Acc: 87.05%
# Epoch: 24 | Epoch Time: 0m 2s
# 	Train Loss: 0.014 | Train Acc: 99.48%
# 	 Val. Loss: 1.141 |  Val. Acc: 87.92%
# Epoch: 25 | Epoch Time: 0m 2s
# 	Train Loss: 0.016 | Train Acc: 99.44%
# 	 Val. Loss: 1.169 |  Val. Acc: 86.31%
# Epoch: 26 | Epoch Time: 0m 2s
# 	Train Loss: 0.017 | Train Acc: 99.42%
# 	 Val. Loss: 1.039 |  Val. Acc: 87.66%
# Epoch: 27 | Epoch Time: 0m 2s
# 	Train Loss: 0.010 | Train Acc: 99.61%
# 	 Val. Loss: 1.161 |  Val. Acc: 87.74%
# Epoch: 28 | Epoch Time: 0m 2s
# 	Train Loss: 0.006 | Train Acc: 99.80%
# 	 Val. Loss: 1.270 |  Val. Acc: 87.48%
# Epoch: 29 | Epoch Time: 0m 2s
# 	Train Loss: 0.019 | Train Acc: 99.24%
# 	 Val. Loss: 1.392 |  Val. Acc: 84.53%
# Epoch: 30 | Epoch Time: 0m 2s
# 	Train Loss: 0.017 | Train Acc: 99.18%
# 	 Val. Loss: 1.203 |  Val. Acc: 87.48%
# Epoch: 31 | Epoch Time: 0m 2s
# 	Train Loss: 0.015 | Train Acc: 99.38%
# 	 Val. Loss: 1.226 |  Val. Acc: 87.06%
# Epoch: 32 | Epoch Time: 0m 2s
# 	Train Loss: 0.007 | Train Acc: 99.77%
# 	 Val. Loss: 1.383 |  Val. Acc: 87.68%
# Epoch: 33 | Epoch Time: 0m 2s
# 	Train Loss: 0.007 | Train Acc: 99.75%
# 	 Val. Loss: 1.814 |  Val. Acc: 83.86%
# Epoch: 34 | Epoch Time: 0m 2s
# 	Train Loss: 0.015 | Train Acc: 99.34%
# 	 Val. Loss: 1.156 |  Val. Acc: 87.86%
# Epoch: 35 | Epoch Time: 0m 2s
# 	Train Loss: 0.012 | Train Acc: 99.53%
# 	 Val. Loss: 2.656 |  Val. Acc: 78.46%
# Epoch: 36 | Epoch Time: 0m 2s
# 	Train Loss: 0.026 | Train Acc: 99.05%
# 	 Val. Loss: 1.120 |  Val. Acc: 87.34%
# Epoch: 37 | Epoch Time: 0m 2s
# 	Train Loss: 0.010 | Train Acc: 99.63%
# 	 Val. Loss: 1.303 |  Val. Acc: 86.99%
# Epoch: 38 | Epoch Time: 0m 2s
# 	Train Loss: 0.016 | Train Acc: 99.38%
# 	 Val. Loss: 1.278 |  Val. Acc: 87.28%
# Epoch: 39 | Epoch Time: 0m 2s
# 	Train Loss: 0.021 | Train Acc: 99.49%
# 	 Val. Loss: 1.228 |  Val. Acc: 87.10%
# Epoch: 40 | Epoch Time: 0m 2s
# 	Train Loss: 0.009 | Train Acc: 99.46%
# 	 Val. Loss: 1.343 |  Val. Acc: 87.78%
# Epoch: 41 | Epoch Time: 0m 2s
# 	Train Loss: 0.016 | Train Acc: 99.44%
# 	 Val. Loss: 1.418 |  Val. Acc: 87.86%
# Epoch: 42 | Epoch Time: 0m 2s
# 	Train Loss: 0.017 | Train Acc: 99.46%
# 	 Val. Loss: 1.505 |  Val. Acc: 85.82%
# Epoch: 43 | Epoch Time: 0m 2s
# 	Train Loss: 0.008 | Train Acc: 99.67%
# 	 Val. Loss: 1.316 |  Val. Acc: 87.32%
# Epoch: 44 | Epoch Time: 0m 2s
# 	Train Loss: 0.002 | Train Acc: 99.98%
# 	 Val. Loss: 1.500 |  Val. Acc: 87.78%
# Epoch: 45 | Epoch Time: 0m 2s
# 	Train Loss: 0.030 | Train Acc: 99.25%
# 	 Val. Loss: 1.257 |  Val. Acc: 86.10%
# Epoch: 46 | Epoch Time: 0m 2s
# 	Train Loss: 0.008 | Train Acc: 99.72%
# 	 Val. Loss: 1.266 |  Val. Acc: 87.48%
# Epoch: 47 | Epoch Time: 0m 2s
# 	Train Loss: 0.011 | Train Acc: 99.65%
# 	 Val. Loss: 1.351 |  Val. Acc: 87.76%
# Epoch: 48 | Epoch Time: 0m 2s
# 	Train Loss: 0.012 | Train Acc: 99.68%
# 	 Val. Loss: 1.491 |  Val. Acc: 87.78%
# Epoch: 49 | Epoch Time: 0m 2s
# 	Train Loss: 0.002 | Train Acc: 99.97%
# 	 Val. Loss: 1.776 |  Val. Acc: 87.44%
# Epoch: 50 | Epoch Time: 0m 2s
# 	Train Loss: 0.040 | Train Acc: 99.25%
# 	 Val. Loss: 1.089 |  Val. Acc: 87.86%
# done FFN2
# saved total_model_FFN2.pt
# Epoch: 01 | Epoch Time: 0m 2s
# 	Train Loss: 0.537 | Train Acc: 71.95%
# 	 Val. Loss: 0.412 |  Val. Acc: 82.04%
# Epoch: 02 | Epoch Time: 0m 2s
# 	Train Loss: 0.337 | Train Acc: 85.64%
# 	 Val. Loss: 0.399 |  Val. Acc: 83.41%
# Epoch: 03 | Epoch Time: 0m 2s
# 	Train Loss: 0.244 | Train Acc: 90.35%
# 	 Val. Loss: 0.347 |  Val. Acc: 85.86%
# Epoch: 04 | Epoch Time: 0m 2s
# 	Train Loss: 0.184 | Train Acc: 93.37%
# 	 Val. Loss: 0.316 |  Val. Acc: 87.22%
# Epoch: 05 | Epoch Time: 0m 2s
# 	Train Loss: 0.130 | Train Acc: 95.46%
# 	 Val. Loss: 0.405 |  Val. Acc: 85.98%
# Epoch: 06 | Epoch Time: 0m 2s
# 	Train Loss: 0.099 | Train Acc: 96.63%
# 	 Val. Loss: 0.496 |  Val. Acc: 87.48%
# Epoch: 07 | Epoch Time: 0m 2s
# 	Train Loss: 0.112 | Train Acc: 96.44%
# 	 Val. Loss: 0.497 |  Val. Acc: 86.61%
# Epoch: 08 | Epoch Time: 0m 2s
# 	Train Loss: 0.069 | Train Acc: 98.21%
# 	 Val. Loss: 0.543 |  Val. Acc: 87.52%
# Epoch: 09 | Epoch Time: 0m 2s
# 	Train Loss: 0.071 | Train Acc: 97.98%
# 	 Val. Loss: 0.684 |  Val. Acc: 86.21%
# Epoch: 10 | Epoch Time: 0m 2s
# 	Train Loss: 0.078 | Train Acc: 98.29%
# 	 Val. Loss: 0.574 |  Val. Acc: 87.56%
# Epoch: 11 | Epoch Time: 0m 2s
# 	Train Loss: 0.029 | Train Acc: 99.07%
# 	 Val. Loss: 0.643 |  Val. Acc: 87.42%
# Epoch: 12 | Epoch Time: 0m 2s
# 	Train Loss: 0.047 | Train Acc: 98.11%
# 	 Val. Loss: 0.457 |  Val. Acc: 86.59%
# Epoch: 13 | Epoch Time: 0m 2s
# 	Train Loss: 0.024 | Train Acc: 98.99%
# 	 Val. Loss: 0.790 |  Val. Acc: 87.40%
# Epoch: 14 | Epoch Time: 0m 2s
# 	Train Loss: 0.044 | Train Acc: 98.34%
# 	 Val. Loss: 0.768 |  Val. Acc: 86.93%
# Epoch: 15 | Epoch Time: 0m 2s
# 	Train Loss: 0.024 | Train Acc: 99.41%
# 	 Val. Loss: 0.948 |  Val. Acc: 87.20%
# Epoch: 16 | Epoch Time: 0m 2s
# 	Train Loss: 0.028 | Train Acc: 99.02%
# 	 Val. Loss: 0.874 |  Val. Acc: 86.87%
# Epoch: 17 | Epoch Time: 0m 2s
# 	Train Loss: 0.013 | Train Acc: 99.60%
# 	 Val. Loss: 1.013 |  Val. Acc: 87.01%
# Epoch: 18 | Epoch Time: 0m 2s
# 	Train Loss: 0.011 | Train Acc: 99.46%
# 	 Val. Loss: 1.141 |  Val. Acc: 87.22%
# Epoch: 19 | Epoch Time: 0m 2s
# 	Train Loss: 0.029 | Train Acc: 99.40%
# 	 Val. Loss: 0.775 |  Val. Acc: 87.03%
# Epoch: 20 | Epoch Time: 0m 2s
# 	Train Loss: 0.013 | Train Acc: 99.40%
# 	 Val. Loss: 1.066 |  Val. Acc: 87.72%
# Epoch: 21 | Epoch Time: 0m 2s
# 	Train Loss: 0.018 | Train Acc: 99.21%
# 	 Val. Loss: 1.028 |  Val. Acc: 87.38%
# Epoch: 22 | Epoch Time: 0m 2s
# 	Train Loss: 0.016 | Train Acc: 99.24%
# 	 Val. Loss: 1.012 |  Val. Acc: 86.69%
# Epoch: 23 | Epoch Time: 0m 2s
# 	Train Loss: 0.038 | Train Acc: 99.30%
# 	 Val. Loss: 0.500 |  Val. Acc: 82.91%
# Epoch: 24 | Epoch Time: 0m 2s
# 	Train Loss: 0.051 | Train Acc: 98.93%
# 	 Val. Loss: 0.581 |  Val. Acc: 86.57%
# Epoch: 25 | Epoch Time: 0m 2s
# 	Train Loss: 0.015 | Train Acc: 99.45%
# 	 Val. Loss: 0.918 |  Val. Acc: 87.40%
# Epoch: 26 | Epoch Time: 0m 2s
# 	Train Loss: 0.027 | Train Acc: 99.11%
# 	 Val. Loss: 0.972 |  Val. Acc: 87.42%
# Epoch: 27 | Epoch Time: 0m 2s
# 	Train Loss: 0.012 | Train Acc: 99.26%
# 	 Val. Loss: 1.196 |  Val. Acc: 87.30%
# Epoch: 28 | Epoch Time: 0m 2s
# 	Train Loss: 0.026 | Train Acc: 99.41%
# 	 Val. Loss: 1.308 |  Val. Acc: 86.12%
# Epoch: 29 | Epoch Time: 0m 2s
# 	Train Loss: 0.012 | Train Acc: 99.56%
# 	 Val. Loss: 1.104 |  Val. Acc: 87.60%
# Epoch: 30 | Epoch Time: 0m 2s
# 	Train Loss: 0.012 | Train Acc: 99.43%
# 	 Val. Loss: 1.220 |  Val. Acc: 87.38%
# Epoch: 31 | Epoch Time: 0m 2s
# 	Train Loss: 0.032 | Train Acc: 99.08%
# 	 Val. Loss: 1.019 |  Val. Acc: 85.88%
# Epoch: 32 | Epoch Time: 0m 2s
# 	Train Loss: 0.012 | Train Acc: 99.20%
# 	 Val. Loss: 1.054 |  Val. Acc: 87.12%
# Epoch: 33 | Epoch Time: 0m 2s
# 	Train Loss: 0.017 | Train Acc: 99.24%
# 	 Val. Loss: 1.132 |  Val. Acc: 84.79%
# Epoch: 34 | Epoch Time: 0m 2s
# 	Train Loss: 0.013 | Train Acc: 99.32%
# 	 Val. Loss: 1.059 |  Val. Acc: 86.99%
# Epoch: 35 | Epoch Time: 0m 2s
# 	Train Loss: 0.014 | Train Acc: 99.13%
# 	 Val. Loss: 1.059 |  Val. Acc: 86.65%
# Epoch: 36 | Epoch Time: 0m 2s
# 	Train Loss: 0.016 | Train Acc: 98.91%
# 	 Val. Loss: 1.001 |  Val. Acc: 86.97%
# Epoch: 37 | Epoch Time: 0m 2s
# 	Train Loss: 0.018 | Train Acc: 99.10%
# 	 Val. Loss: 0.960 |  Val. Acc: 86.61%
# Epoch: 38 | Epoch Time: 0m 2s
# 	Train Loss: 0.015 | Train Acc: 99.29%
# 	 Val. Loss: 1.175 |  Val. Acc: 87.64%
# Epoch: 39 | Epoch Time: 0m 2s
# 	Train Loss: 0.010 | Train Acc: 99.48%
# 	 Val. Loss: 1.192 |  Val. Acc: 88.01%
# Epoch: 40 | Epoch Time: 0m 2s
# 	Train Loss: 0.023 | Train Acc: 99.16%
# 	 Val. Loss: 1.122 |  Val. Acc: 87.68%
# Epoch: 41 | Epoch Time: 0m 2s
# 	Train Loss: 0.011 | Train Acc: 99.25%
# 	 Val. Loss: 1.030 |  Val. Acc: 86.17%
# Epoch: 42 | Epoch Time: 0m 2s
# 	Train Loss: 0.014 | Train Acc: 99.15%
# 	 Val. Loss: 0.843 |  Val. Acc: 87.18%
# Epoch: 43 | Epoch Time: 0m 2s
# 	Train Loss: 0.027 | Train Acc: 99.09%
# 	 Val. Loss: 0.909 |  Val. Acc: 86.17%
# Epoch: 44 | Epoch Time: 0m 2s
# 	Train Loss: 0.018 | Train Acc: 99.07%
# 	 Val. Loss: 1.239 |  Val. Acc: 87.36%
# Epoch: 45 | Epoch Time: 0m 2s
# 	Train Loss: 0.007 | Train Acc: 99.60%
# 	 Val. Loss: 1.416 |  Val. Acc: 87.46%
# Epoch: 46 | Epoch Time: 0m 2s
# 	Train Loss: 0.030 | Train Acc: 99.04%
# 	 Val. Loss: 1.009 |  Val. Acc: 86.59%
# Epoch: 47 | Epoch Time: 0m 2s
# 	Train Loss: 0.007 | Train Acc: 99.61%
# 	 Val. Loss: 1.465 |  Val. Acc: 87.66%
# Epoch: 48 | Epoch Time: 0m 2s
# 	Train Loss: 0.025 | Train Acc: 99.34%
# 	 Val. Loss: 1.292 |  Val. Acc: 87.66%
# Epoch: 49 | Epoch Time: 0m 2s
# 	Train Loss: 0.010 | Train Acc: 99.48%
# 	 Val. Loss: 1.619 |  Val. Acc: 87.44%
# Epoch: 50 | Epoch Time: 0m 2s
# 	Train Loss: 0.012 | Train Acc: 99.56%
# 	 Val. Loss: 1.189 |  Val. Acc: 86.89%
# done FFN3
# saved total_model_FFN3.pt
# Epoch: 01 | Epoch Time: 0m 8s
# 	Train Loss: 0.476 | Train Acc: 76.63%
# 	 Val. Loss: 0.357 |  Val. Acc: 84.34%
# Epoch: 02 | Epoch Time: 0m 5s
# 	Train Loss: 0.264 | Train Acc: 89.65%
# 	 Val. Loss: 0.302 |  Val. Acc: 87.03%
# Epoch: 03 | Epoch Time: 0m 4s
# 	Train Loss: 0.173 | Train Acc: 93.88%
# 	 Val. Loss: 0.327 |  Val. Acc: 86.33%
# Epoch: 04 | Epoch Time: 0m 4s
# 	Train Loss: 0.086 | Train Acc: 98.13%
# 	 Val. Loss: 0.287 |  Val. Acc: 88.59%
# Epoch: 05 | Epoch Time: 0m 4s
# 	Train Loss: 0.044 | Train Acc: 99.63%
# 	 Val. Loss: 0.375 |  Val. Acc: 86.06%
# Epoch: 06 | Epoch Time: 0m 4s
# 	Train Loss: 0.020 | Train Acc: 99.93%
# 	 Val. Loss: 0.318 |  Val. Acc: 88.09%
# Epoch: 07 | Epoch Time: 0m 4s
# 	Train Loss: 0.009 | Train Acc: 99.99%
# 	 Val. Loss: 0.308 |  Val. Acc: 89.06%
# Epoch: 08 | Epoch Time: 0m 4s
# 	Train Loss: 0.005 | Train Acc: 100.00%
# 	 Val. Loss: 0.320 |  Val. Acc: 89.08%
# Epoch: 09 | Epoch Time: 0m 4s
# 	Train Loss: 0.003 | Train Acc: 100.00%
# 	 Val. Loss: 0.331 |  Val. Acc: 88.81%
# Epoch: 10 | Epoch Time: 0m 4s
# 	Train Loss: 0.003 | Train Acc: 100.00%
# 	 Val. Loss: 0.339 |  Val. Acc: 88.86%
# Epoch: 11 | Epoch Time: 0m 4s
# 	Train Loss: 0.002 | Train Acc: 100.00%
# 	 Val. Loss: 0.346 |  Val. Acc: 88.88%
# Epoch: 12 | Epoch Time: 0m 4s
# 	Train Loss: 0.001 | Train Acc: 100.00%
# 	 Val. Loss: 0.353 |  Val. Acc: 88.96%
# Epoch: 13 | Epoch Time: 0m 4s
# 	Train Loss: 0.001 | Train Acc: 100.00%
# 	 Val. Loss: 0.359 |  Val. Acc: 89.08%
# Epoch: 14 | Epoch Time: 0m 4s
# 	Train Loss: 0.001 | Train Acc: 100.00%
# 	 Val. Loss: 0.367 |  Val. Acc: 88.90%
# Epoch: 15 | Epoch Time: 0m 4s
# 	Train Loss: 0.001 | Train Acc: 100.00%
# 	 Val. Loss: 0.373 |  Val. Acc: 88.94%
# Epoch: 16 | Epoch Time: 0m 4s
# 	Train Loss: 0.001 | Train Acc: 100.00%
# 	 Val. Loss: 0.379 |  Val. Acc: 89.16%
# Epoch: 17 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.388 |  Val. Acc: 88.96%
# Epoch: 18 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.393 |  Val. Acc: 89.00%
# Epoch: 19 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.400 |  Val. Acc: 89.00%
# Epoch: 20 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.407 |  Val. Acc: 88.90%
# Epoch: 21 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.412 |  Val. Acc: 89.08%
# Epoch: 22 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.420 |  Val. Acc: 88.92%
# Epoch: 23 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.424 |  Val. Acc: 89.08%
# Epoch: 24 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.431 |  Val. Acc: 89.08%
# Epoch: 25 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.437 |  Val. Acc: 88.90%
# Epoch: 26 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.442 |  Val. Acc: 89.10%
# Epoch: 27 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.448 |  Val. Acc: 89.04%
# Epoch: 28 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.454 |  Val. Acc: 89.14%
# Epoch: 29 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.460 |  Val. Acc: 89.14%
# Epoch: 30 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.467 |  Val. Acc: 89.06%
# Epoch: 31 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.474 |  Val. Acc: 89.06%
# Epoch: 32 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.479 |  Val. Acc: 89.04%
# Epoch: 33 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.486 |  Val. Acc: 89.06%
# Epoch: 34 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.492 |  Val. Acc: 89.12%
# Epoch: 35 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.497 |  Val. Acc: 89.18%
# Epoch: 36 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.503 |  Val. Acc: 89.08%
# Epoch: 37 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.509 |  Val. Acc: 89.10%
# Epoch: 38 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.515 |  Val. Acc: 89.16%
# Epoch: 39 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.521 |  Val. Acc: 89.12%
# Epoch: 40 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.526 |  Val. Acc: 89.16%
# Epoch: 41 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.531 |  Val. Acc: 89.16%
# Epoch: 42 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.538 |  Val. Acc: 89.16%
# Epoch: 43 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.544 |  Val. Acc: 89.22%
# Epoch: 44 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.550 |  Val. Acc: 89.16%
# Epoch: 45 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.557 |  Val. Acc: 89.28%
# Epoch: 46 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.561 |  Val. Acc: 89.20%
# Epoch: 47 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.569 |  Val. Acc: 89.26%
# Epoch: 48 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.573 |  Val. Acc: 89.32%
# Epoch: 49 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.581 |  Val. Acc: 89.30%
# Epoch: 50 | Epoch Time: 0m 4s
# 	Train Loss: 0.000 | Train Acc: 100.00%
# 	 Val. Loss: 0.585 |  Val. Acc: 89.32%
# done CNN
# saved total_model_CNN.pt
# Epoch: 01 | Epoch Time: 0m 7s
# 	Train Loss: 0.678 | Train Acc: 57.88%
# 	 Val. Loss: 0.637 |  Val. Acc: 63.73%
# Epoch: 02 | Epoch Time: 0m 7s
# 	Train Loss: 0.628 | Train Acc: 65.71%
# 	 Val. Loss: 0.586 |  Val. Acc: 70.35%
# Epoch: 03 | Epoch Time: 0m 7s
# 	Train Loss: 0.558 | Train Acc: 72.33%
# 	 Val. Loss: 0.604 |  Val. Acc: 67.90%
# Epoch: 04 | Epoch Time: 0m 7s
# 	Train Loss: 0.564 | Train Acc: 72.07%
# 	 Val. Loss: 0.500 |  Val. Acc: 76.84%
# Epoch: 05 | Epoch Time: 0m 7s
# 	Train Loss: 0.496 | Train Acc: 76.58%
# 	 Val. Loss: 0.465 |  Val. Acc: 79.00%
# Epoch: 06 | Epoch Time: 0m 7s
# 	Train Loss: 0.356 | Train Acc: 84.86%
# 	 Val. Loss: 0.373 |  Val. Acc: 82.91%
# Epoch: 07 | Epoch Time: 0m 7s
# 	Train Loss: 0.293 | Train Acc: 87.84%
# 	 Val. Loss: 0.518 |  Val. Acc: 74.62%
# Epoch: 08 | Epoch Time: 0m 7s
# 	Train Loss: 0.287 | Train Acc: 88.69%
# 	 Val. Loss: 0.353 |  Val. Acc: 85.30%
# Epoch: 09 | Epoch Time: 0m 7s
# 	Train Loss: 0.233 | Train Acc: 91.10%
# 	 Val. Loss: 0.333 |  Val. Acc: 86.37%
# Epoch: 10 | Epoch Time: 0m 7s
# 	Train Loss: 0.172 | Train Acc: 93.88%
# 	 Val. Loss: 0.340 |  Val. Acc: 86.41%
# Epoch: 11 | Epoch Time: 0m 7s
# 	Train Loss: 0.143 | Train Acc: 94.91%
# 	 Val. Loss: 0.356 |  Val. Acc: 85.74%
# Epoch: 12 | Epoch Time: 0m 7s
# 	Train Loss: 0.116 | Train Acc: 95.98%
# 	 Val. Loss: 0.369 |  Val. Acc: 87.14%
# Epoch: 13 | Epoch Time: 0m 7s
# 	Train Loss: 0.104 | Train Acc: 96.53%
# 	 Val. Loss: 0.380 |  Val. Acc: 86.77%
# Epoch: 14 | Epoch Time: 0m 7s
# 	Train Loss: 0.084 | Train Acc: 97.25%
# 	 Val. Loss: 0.453 |  Val. Acc: 84.77%
# Epoch: 15 | Epoch Time: 0m 7s
# 	Train Loss: 0.090 | Train Acc: 97.07%
# 	 Val. Loss: 0.399 |  Val. Acc: 86.65%
# Epoch: 16 | Epoch Time: 0m 7s
# 	Train Loss: 0.093 | Train Acc: 96.89%
# 	 Val. Loss: 0.397 |  Val. Acc: 86.51%
# Epoch: 17 | Epoch Time: 0m 7s
# 	Train Loss: 0.080 | Train Acc: 97.29%
# 	 Val. Loss: 0.413 |  Val. Acc: 84.89%
# Epoch: 18 | Epoch Time: 0m 7s
# 	Train Loss: 0.048 | Train Acc: 98.57%
# 	 Val. Loss: 0.492 |  Val. Acc: 86.93%
# Epoch: 19 | Epoch Time: 0m 7s
# 	Train Loss: 0.041 | Train Acc: 98.75%
# 	 Val. Loss: 0.500 |  Val. Acc: 86.25%
# Epoch: 20 | Epoch Time: 0m 7s
# 	Train Loss: 0.046 | Train Acc: 98.58%
# 	 Val. Loss: 0.470 |  Val. Acc: 86.93%
# Epoch: 21 | Epoch Time: 0m 7s
# 	Train Loss: 0.044 | Train Acc: 98.72%
# 	 Val. Loss: 0.489 |  Val. Acc: 87.30%
# Epoch: 22 | Epoch Time: 0m 7s
# 	Train Loss: 0.033 | Train Acc: 98.96%
# 	 Val. Loss: 0.460 |  Val. Acc: 86.81%
# Epoch: 23 | Epoch Time: 0m 7s
# 	Train Loss: 0.032 | Train Acc: 99.08%
# 	 Val. Loss: 0.475 |  Val. Acc: 86.83%
# Epoch: 24 | Epoch Time: 0m 7s
# 	Train Loss: 0.032 | Train Acc: 99.04%
# 	 Val. Loss: 0.472 |  Val. Acc: 85.88%
# Epoch: 25 | Epoch Time: 0m 7s
# 	Train Loss: 0.045 | Train Acc: 98.69%
# 	 Val. Loss: 0.527 |  Val. Acc: 86.63%
# Epoch: 26 | Epoch Time: 0m 7s
# 	Train Loss: 0.027 | Train Acc: 99.26%
# 	 Val. Loss: 0.849 |  Val. Acc: 83.31%
# Epoch: 27 | Epoch Time: 0m 7s
# 	Train Loss: 0.062 | Train Acc: 97.98%
# 	 Val. Loss: 0.532 |  Val. Acc: 87.03%
# Epoch: 28 | Epoch Time: 0m 7s
# 	Train Loss: 0.025 | Train Acc: 99.22%
# 	 Val. Loss: 0.544 |  Val. Acc: 87.12%
# Epoch: 29 | Epoch Time: 0m 7s
# 	Train Loss: 0.019 | Train Acc: 99.44%
# 	 Val. Loss: 0.561 |  Val. Acc: 87.36%
# Epoch: 30 | Epoch Time: 0m 7s
# 	Train Loss: 0.022 | Train Acc: 99.33%
# 	 Val. Loss: 0.550 |  Val. Acc: 85.74%
# Epoch: 31 | Epoch Time: 0m 7s
# 	Train Loss: 0.020 | Train Acc: 99.42%
# 	 Val. Loss: 0.624 |  Val. Acc: 87.40%
# Epoch: 32 | Epoch Time: 0m 7s
# 	Train Loss: 0.023 | Train Acc: 99.22%
# 	 Val. Loss: 0.539 |  Val. Acc: 86.87%
# Epoch: 33 | Epoch Time: 0m 7s
# 	Train Loss: 0.018 | Train Acc: 99.47%
# 	 Val. Loss: 0.614 |  Val. Acc: 87.28%
# Epoch: 34 | Epoch Time: 0m 7s
# 	Train Loss: 0.024 | Train Acc: 99.19%
# 	 Val. Loss: 0.579 |  Val. Acc: 87.12%
# Epoch: 35 | Epoch Time: 0m 7s
# 	Train Loss: 0.016 | Train Acc: 99.51%
# 	 Val. Loss: 0.563 |  Val. Acc: 87.42%
# Epoch: 36 | Epoch Time: 0m 7s
# 	Train Loss: 0.017 | Train Acc: 99.37%
# 	 Val. Loss: 0.552 |  Val. Acc: 86.45%
# Epoch: 37 | Epoch Time: 0m 7s
# 	Train Loss: 0.015 | Train Acc: 99.52%
# 	 Val. Loss: 0.598 |  Val. Acc: 87.76%
# Epoch: 38 | Epoch Time: 0m 7s
# 	Train Loss: 0.017 | Train Acc: 99.44%
# 	 Val. Loss: 0.546 |  Val. Acc: 87.54%
# Epoch: 39 | Epoch Time: 0m 7s
# 	Train Loss: 0.015 | Train Acc: 99.47%
# 	 Val. Loss: 0.642 |  Val. Acc: 86.00%
# Epoch: 40 | Epoch Time: 0m 7s
# 	Train Loss: 0.019 | Train Acc: 99.39%
# 	 Val. Loss: 0.532 |  Val. Acc: 87.10%
# Epoch: 41 | Epoch Time: 0m 7s
# 	Train Loss: 0.014 | Train Acc: 99.49%
# 	 Val. Loss: 0.610 |  Val. Acc: 87.80%
# Epoch: 42 | Epoch Time: 0m 7s
# 	Train Loss: 0.011 | Train Acc: 99.57%
# 	 Val. Loss: 0.582 |  Val. Acc: 87.48%
# Epoch: 43 | Epoch Time: 0m 7s
# 	Train Loss: 0.013 | Train Acc: 99.62%
# 	 Val. Loss: 0.609 |  Val. Acc: 87.68%
# Epoch: 44 | Epoch Time: 0m 7s
# 	Train Loss: 0.013 | Train Acc: 99.47%
# 	 Val. Loss: 0.668 |  Val. Acc: 87.82%
# Epoch: 45 | Epoch Time: 0m 7s
# 	Train Loss: 0.018 | Train Acc: 99.35%
# 	 Val. Loss: 0.561 |  Val. Acc: 86.81%
# Epoch: 46 | Epoch Time: 0m 7s
# 	Train Loss: 0.013 | Train Acc: 99.58%
# 	 Val. Loss: 0.681 |  Val. Acc: 86.10%
# Epoch: 47 | Epoch Time: 0m 7s
# 	Train Loss: 0.008 | Train Acc: 99.65%
# 	 Val. Loss: 0.644 |  Val. Acc: 87.76%
# Epoch: 48 | Epoch Time: 0m 7s
# 	Train Loss: 0.011 | Train Acc: 99.54%
# 	 Val. Loss: 0.656 |  Val. Acc: 86.77%
# Epoch: 49 | Epoch Time: 0m 7s
# 	Train Loss: 0.009 | Train Acc: 99.67%
# 	 Val. Loss: 0.706 |  Val. Acc: 87.78%
# Epoch: 50 | Epoch Time: 0m 7s
# 	Train Loss: 0.016 | Train Acc: 99.45%
# 	 Val. Loss: 0.598 |  Val. Acc: 87.56%
# done LSTM
# saved total_model_LSTM.pt
# Epoch: 01 | Epoch Time: 0m 9s
# 	Train Loss: 0.681 | Train Acc: 56.14%
# 	 Val. Loss: 0.703 |  Val. Acc: 55.16%
# Epoch: 02 | Epoch Time: 0m 9s
# 	Train Loss: 0.617 | Train Acc: 66.30%
# 	 Val. Loss: 0.589 |  Val. Acc: 69.17%
# Epoch: 03 | Epoch Time: 0m 9s
# 	Train Loss: 0.539 | Train Acc: 73.42%
# 	 Val. Loss: 0.572 |  Val. Acc: 69.74%
# Epoch: 04 | Epoch Time: 0m 9s
# 	Train Loss: 0.451 | Train Acc: 79.57%
# 	 Val. Loss: 0.522 |  Val. Acc: 74.68%
# Epoch: 05 | Epoch Time: 0m 9s
# 	Train Loss: 0.464 | Train Acc: 78.55%
# 	 Val. Loss: 0.481 |  Val. Acc: 80.24%
# Epoch: 06 | Epoch Time: 0m 9s
# 	Train Loss: 0.378 | Train Acc: 83.59%
# 	 Val. Loss: 0.450 |  Val. Acc: 80.70%
# Epoch: 07 | Epoch Time: 0m 9s
# 	Train Loss: 0.265 | Train Acc: 89.42%
# 	 Val. Loss: 0.406 |  Val. Acc: 82.36%
# Epoch: 08 | Epoch Time: 0m 9s
# 	Train Loss: 0.220 | Train Acc: 91.56%
# 	 Val. Loss: 0.420 |  Val. Acc: 82.48%
# Epoch: 09 | Epoch Time: 0m 9s
# 	Train Loss: 0.162 | Train Acc: 93.91%
# 	 Val. Loss: 0.433 |  Val. Acc: 85.72%
# Epoch: 10 | Epoch Time: 0m 9s
# 	Train Loss: 0.134 | Train Acc: 95.19%
# 	 Val. Loss: 0.482 |  Val. Acc: 83.33%
# Epoch: 11 | Epoch Time: 0m 9s
# 	Train Loss: 0.103 | Train Acc: 96.46%
# 	 Val. Loss: 0.507 |  Val. Acc: 84.32%
# Epoch: 12 | Epoch Time: 0m 9s
# 	Train Loss: 0.065 | Train Acc: 97.81%
# 	 Val. Loss: 0.595 |  Val. Acc: 82.93%
# Epoch: 13 | Epoch Time: 0m 9s
# 	Train Loss: 0.050 | Train Acc: 98.32%
# 	 Val. Loss: 0.714 |  Val. Acc: 84.04%
# Epoch: 14 | Epoch Time: 0m 9s
# 	Train Loss: 0.055 | Train Acc: 98.09%
# 	 Val. Loss: 0.630 |  Val. Acc: 83.98%
# Epoch: 15 | Epoch Time: 0m 9s
# 	Train Loss: 0.025 | Train Acc: 99.17%
# 	 Val. Loss: 0.812 |  Val. Acc: 80.89%
# Epoch: 16 | Epoch Time: 0m 9s
# 	Train Loss: 0.023 | Train Acc: 99.25%
# 	 Val. Loss: 0.754 |  Val. Acc: 83.25%
# Epoch: 17 | Epoch Time: 0m 9s
# 	Train Loss: 0.022 | Train Acc: 99.19%
# 	 Val. Loss: 0.772 |  Val. Acc: 83.17%
# Epoch: 18 | Epoch Time: 0m 9s
# 	Train Loss: 0.014 | Train Acc: 99.58%
# 	 Val. Loss: 0.873 |  Val. Acc: 83.35%
# Epoch: 19 | Epoch Time: 0m 9s
# 	Train Loss: 0.010 | Train Acc: 99.63%
# 	 Val. Loss: 0.948 |  Val. Acc: 84.32%
# Epoch: 20 | Epoch Time: 0m 9s
# 	Train Loss: 0.011 | Train Acc: 99.61%
# 	 Val. Loss: 0.896 |  Val. Acc: 82.10%
# Epoch: 21 | Epoch Time: 0m 9s
# 	Train Loss: 0.019 | Train Acc: 99.25%
# 	 Val. Loss: 0.861 |  Val. Acc: 82.73%
# Epoch: 22 | Epoch Time: 0m 9s
# 	Train Loss: 0.016 | Train Acc: 99.35%
# 	 Val. Loss: 0.960 |  Val. Acc: 82.54%
# Epoch: 23 | Epoch Time: 0m 9s
# 	Train Loss: 0.015 | Train Acc: 99.42%
# 	 Val. Loss: 1.066 |  Val. Acc: 82.24%
# Epoch: 24 | Epoch Time: 0m 9s
# 	Train Loss: 0.012 | Train Acc: 99.43%
# 	 Val. Loss: 1.061 |  Val. Acc: 81.05%
# Epoch: 25 | Epoch Time: 0m 9s
# 	Train Loss: 0.028 | Train Acc: 99.03%
# 	 Val. Loss: 0.856 |  Val. Acc: 83.19%
# Epoch: 26 | Epoch Time: 0m 9s
# 	Train Loss: 0.007 | Train Acc: 99.69%
# 	 Val. Loss: 0.923 |  Val. Acc: 83.94%
# Epoch: 27 | Epoch Time: 0m 9s
# 	Train Loss: 0.004 | Train Acc: 99.82%
# 	 Val. Loss: 1.045 |  Val. Acc: 83.50%
# Epoch: 28 | Epoch Time: 0m 9s
# 	Train Loss: 0.005 | Train Acc: 99.81%
# 	 Val. Loss: 1.193 |  Val. Acc: 84.12%
# Epoch: 29 | Epoch Time: 0m 9s
# 	Train Loss: 0.008 | Train Acc: 99.65%
# 	 Val. Loss: 1.111 |  Val. Acc: 83.17%
# Epoch: 30 | Epoch Time: 0m 9s
# 	Train Loss: 0.006 | Train Acc: 99.72%
# 	 Val. Loss: 1.262 |  Val. Acc: 82.58%
# Epoch: 31 | Epoch Time: 0m 9s
# 	Train Loss: 0.015 | Train Acc: 99.45%
# 	 Val. Loss: 0.966 |  Val. Acc: 83.41%
# Epoch: 32 | Epoch Time: 0m 9s
# 	Train Loss: 0.007 | Train Acc: 99.77%
# 	 Val. Loss: 1.051 |  Val. Acc: 84.91%
# Epoch: 33 | Epoch Time: 0m 9s
# 	Train Loss: 0.007 | Train Acc: 99.74%
# 	 Val. Loss: 1.036 |  Val. Acc: 82.22%
# Epoch: 34 | Epoch Time: 0m 9s
# 	Train Loss: 0.005 | Train Acc: 99.78%
# 	 Val. Loss: 1.203 |  Val. Acc: 83.33%
# Epoch: 35 | Epoch Time: 0m 9s
# 	Train Loss: 0.011 | Train Acc: 99.51%
# 	 Val. Loss: 1.019 |  Val. Acc: 83.98%
# Epoch: 36 | Epoch Time: 0m 9s
# 	Train Loss: 0.008 | Train Acc: 99.72%
# 	 Val. Loss: 1.077 |  Val. Acc: 85.72%
# Epoch: 37 | Epoch Time: 0m 9s
# 	Train Loss: 0.013 | Train Acc: 99.47%
# 	 Val. Loss: 1.004 |  Val. Acc: 84.24%
# Epoch: 38 | Epoch Time: 0m 9s
# 	Train Loss: 0.017 | Train Acc: 99.38%
# 	 Val. Loss: 0.972 |  Val. Acc: 82.85%
# Epoch: 39 | Epoch Time: 0m 9s
# 	Train Loss: 0.007 | Train Acc: 99.67%
# 	 Val. Loss: 1.036 |  Val. Acc: 84.61%
# Epoch: 40 | Epoch Time: 0m 9s
# 	Train Loss: 0.004 | Train Acc: 99.81%
# 	 Val. Loss: 1.072 |  Val. Acc: 84.43%
# Epoch: 41 | Epoch Time: 0m 9s
# 	Train Loss: 0.004 | Train Acc: 99.83%
# 	 Val. Loss: 1.113 |  Val. Acc: 84.71%
# Epoch: 42 | Epoch Time: 0m 9s
# 	Train Loss: 0.007 | Train Acc: 99.72%
# 	 Val. Loss: 1.124 |  Val. Acc: 83.96%
# Epoch: 43 | Epoch Time: 0m 9s
# 	Train Loss: 0.004 | Train Acc: 99.78%
# 	 Val. Loss: 1.097 |  Val. Acc: 81.61%
# Epoch: 44 | Epoch Time: 0m 9s
# 	Train Loss: 0.012 | Train Acc: 99.54%
# 	 Val. Loss: 0.956 |  Val. Acc: 83.15%
# Epoch: 45 | Epoch Time: 0m 9s
# 	Train Loss: 0.006 | Train Acc: 99.71%
# 	 Val. Loss: 1.080 |  Val. Acc: 84.61%
# Epoch: 46 | Epoch Time: 0m 9s
# 	Train Loss: 0.003 | Train Acc: 99.76%
# 	 Val. Loss: 1.134 |  Val. Acc: 84.75%
# Epoch: 47 | Epoch Time: 0m 9s
# 	Train Loss: 0.006 | Train Acc: 99.76%
# 	 Val. Loss: 1.051 |  Val. Acc: 84.51%
# Epoch: 48 | Epoch Time: 0m 9s
# 	Train Loss: 0.003 | Train Acc: 99.80%
# 	 Val. Loss: 1.156 |  Val. Acc: 83.48%
# Epoch: 49 | Epoch Time: 0m 9s
# 	Train Loss: 0.003 | Train Acc: 99.86%
# 	 Val. Loss: 1.190 |  Val. Acc: 84.10%
# Epoch: 50 | Epoch Time: 0m 9s
# 	Train Loss: 0.006 | Train Acc: 99.68%
# 	 Val. Loss: 1.197 |  Val. Acc: 83.07%
# done BiLSTM
# saved total_model_BiLSTM.pt

# %% [markdown]
# You may have noticed the loss is not really decreasing and the accuracy is poor. This is due to several issues with the model which we'll improve in the next notebook.
#
# Finally, the metric we actually care about, the test loss and accuracy, which we get from our parameters that gave us the best validation loss.

# %%
for name in models.keys():
  print(name)
  model = torch.load(f"total_model_{name}.pt")
  model.load_state_dict(torch.load(f"model_{name}_best_valid_loss.pt"))

  test_loss, test_acc = evaluate(model, test_iterator, criterion)

  print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}%')
# Out:
# FFN1
# Test Loss: 0.335 | Test Acc: 86.75%
# FFN2
# Test Loss: 0.345 | Test Acc: 85.94%
# FFN3
# Test Loss: 0.349 | Test Acc: 85.96%
# CNN
# Test Loss: 0.280 | Test Acc: 88.43%
# LSTM
# Test Loss: 0.343 | Test Acc: 85.95%
# BiLSTM
# Test Loss: 0.443 | Test Acc: 80.31%

# %%
# for all models in the lossesDict, make one plot
import matplotlib.pyplot as plt

# Plotting
plt.figure(figsize=(10, 6))
for model_name, losses in lossesDict.items():
    plt.plot(losses, label=model_name)

plt.title('Model Losses Comparison')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Next Steps
#
# In the next notebook, the improvements we will make are:
# - packed padded sequences
# - pre-trained word embeddings
# - different RNN architecture
# - bidirectional RNN
# - multi-layer RNN
# - regularization
# - a different optimizer
#
# This will allow us to achieve ~84% accuracy.
